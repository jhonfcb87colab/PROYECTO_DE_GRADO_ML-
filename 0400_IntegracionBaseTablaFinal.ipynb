# %% [markdown]
# ### Integracion de informacion con las dimensiones
# #### Estructuracion en spark

# %%
import datetime
import duckdb
import pandas as pd
horainicio = datetime.datetime.now()

# %%
PATH_PRINCIPAL = "/Volumes/proyectogrado/source/sourcedb"

# %%
archivos_y_carpetas = dbutils.fs.ls(PATH_PRINCIPAL)
# Para imprimir cada elemento:
for elemento in archivos_y_carpetas:
    print(elemento.path)

# %%
ruta_archivo = f"{PATH_PRINCIPAL}/LOG_GUIAS/RAW/LOG_GUIAS_BOGOTA.parquet"

# Pasar la ruta directa del volumen
df_resultado = duckdb.sql(f"""
    SELECT * 
    FROM read_parquet('{ruta_archivo}')
    LIMIT 100
""").df()

display(df_resultado)
